# %%
import numpy as np
import pandas as pd
import requests
import matplotlib
import matplotlib.pyplot as plt

font_path = "C:\Windows\Fonts\HMFMMUEX.TTC"
kfont = matplotlib.font_manager.FontProperties(fname=font_path).get_name()
#print(kfont)

matplotlib.rcParams['font.family'] = [kfont]


pd_data = pd.read_csv('데이터산업_시장규모_20230306153139.csv', encoding='cp949', header=0)



# pd_data.columns = ['시점', '데이터 처리 및 관리 솔루션 개발·공급업', '데이터 구축 및 컨설팅 서비스업', '데이터 판매 및 제공 서비스업']
pd_data['시점'][6] = '2021'
pd_data['시점'][6]
# Out:
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_11284\184464046.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd_data['시점'][6] = '2021'
# '2021'

# %%
pd_data.columns
# Out:
# Index(['시점', '데이터 처리 및 관리 솔루션 개발·공급업', '데이터 구축 및 컨설팅 서비스업',
#        '데이터 판매 및 제공 서비스업'],
#       dtype='object')

# %%
figa = plt.figure(figsize=(7,5), layout='tight')
line_axe = figa.add_subplot(2,1,1)
col_names = pd_data.columns
line_params = ['ro-', 'g^--', 'bv:']
# line_axe.set_title['2015-2021 산업별 규모']
line_axe.set(title='2015-2021 산업별 규모', ylabel='억원')

for i in range(1, 4):
    line_axe.plot(pd_data['시점'], pd_data[col_names[i]], line_params[i-1])
    
pie2015_axe = figa.add_subplot(2,2,3)
pie2015_axe.pie(pd_data.iloc[0, 1:])
pie2015_axe.set_title('2015년 구성비', y=-0.12)


pie2021_axe = figa.add_subplot(2,2,4)
pie2021_axe.set_title('2021년 구성비', y=-0.12)
pie2021_axe.pie(pd_data.iloc[-1, 1:], labels = ('abc'), autopct = '%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x1a5cfa2beb0>,
# ...
#  [Text(1.0062963527639606, 0.4442607909932528, 'a'),
#   Text(-0.4635448352231071, 0.9975601163528857, 'b'),
#   Text(0.021169715733660534, -1.099796273468753, 'c')],
#  [Text(0.548888919689433, 0.2423240678145015, '13.23'),
#   Text(-0.25284263739442203, 0.5441236998288467, '37.38'),
#   Text(0.011547117672905746, -0.5998888764375016, '49.39')])

# %%
fig, axe = plt.subplots()
x = pd_data['시점']
y1 = pd_data['데이터 처리 및 관리 솔루션 개발·공급업']
y2 = pd_data['데이터 구축 및 컨설팅 서비스업']
y3 = pd_data['데이터 판매 및 제공 서비스업']
axe.plot(x, y1, label='데이터 처리 및 관리 솔루션 개발·공급업')
axe.plot(x, y2, label='데이터 구축 및 컨설팅 서비스업')
axe.plot(x, y3, label='데이터 판매 및 제공 서비스업')
axe.set_title(n)  # set the title to the group name
axe.set_xlabel('년도')
axe.set_ylabel('업체 수')
# axe.set_xticks(np.linspace(2015, 2021, 10))
# Out:
# Text(0, 0.5, '업체 수')

# %%
sub_data = pd_data.groupby('시점')

lista = list(sub_data.groups.keys())
print(lista)2
# Out:
# ['2015', '2016', '2017', '2018', '2019', '2020', '2021 e)']

# %%
filter1 = pd_data['데이터직무별(1)']=='데이터 처리 및 관리 솔루션 개발·공급업'
sub_data = pd_data[filter1]

_, axe = plt.subplots()
axe.plot(sub_data['시점'], sub_data.iloc[:,3])
axe.plot(sub_data['시점'], sub_data.iloc[:,4])
