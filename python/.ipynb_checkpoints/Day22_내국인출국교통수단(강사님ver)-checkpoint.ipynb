# %%
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt

pd_data = pd.read_csv('내국인출국교통수단별_20230302165102.csv', encoding='cp949', header=1)



pd_data.drop('계', axis =1, inplace=True)
pd_data.head()

pd_data.columns = ['시점', '공항', '항구']
pd_data.head()

# 공항, 항구 년중 월별 출국 인원 plot
# normalization / standardization 적용, plot
# 2018부터 2022년까지 추이 보기.
# Out:
#         시점    공항    항구
# 0  2022.01   938  3279
# 1  2022.02   855  3179
# 2  2022.03   986  3418
# 3  2022.04  1823  3158
# 4  2022.05  3418  3231

# %%
sub_data2022 = pd_data.tail(12)
print(sub_data2022)
print(sub_data2022.describe())

value_min = sub_data2022['공항'].min()
value_max = sub_data2022['공항'].max()
value_std = sub_data2022['공항'].std()
value_mean = sub_data2022['공항'].mean()
sub_data2022['공항_norm'] = sub_data2022['공항'].apply(lambda x: (x-value_min)/(value_max-value_min))
sub_data2022['공항_std'] = sub_data2022['공항'].apply(lambda x: (x-value_mean)/value_std)

value_min = sub_data2022['항구'].min()
value_max = sub_data2022['항구'].max()
value_std = sub_data2022['항구'].std()
value_mean = sub_data2022['항구'].mean()
sub_data2022['항구_norm'] = sub_data2022['항구'].apply(lambda x: (x-value_min)/(value_max-value_min))
sub_data2022['항구_std'] = sub_data2022['항구'].apply(lambda x: (x-value_mean)/value_std)




_, axe = plt.subplots()
axe.plot(np.arange(1, 13), sub_data2022['공항_norm'])
axe.plot(np.arange(1, 13), sub_data2022['항구_norm'])

_, axe = plt.subplots()
axe.plot(np.arange(1, 13), sub_data2022['공항_std'])
axe.plot(np.arange(1, 13), sub_data2022['항구_std'])
# Out:
#          시점      공항    항구
# 0   2022.01     938  3279
# 1   2022.02     855  3179
# 2   2022.03     986  3418
# 3   2022.04    1823  3158
# 4   2022.05    3418  3231
# 5   2022.06    7835  3105
# 6   2022.07   42841  3326
# 7   2022.08   47261  3533
# 8   2022.09   37030  2682
# 9   2022.10   71579  3494
# 10  2022.11  126419  3687
# 11  2022.12  192723  5760
#                 시점             공항           항구
# count    12.000000      12.000000    12.000000
# mean   2022.065000   44475.666667  3487.666667
# std       0.036056   60324.578943   759.498918
# min    2022.010000     855.000000  2682.000000
# 25%    2022.037500    1613.750000  3173.750000
# 50%    2022.065000   22432.500000  3302.500000
# 75%    2022.092500   53340.500000  3503.750000
# max    2022.120000  192723.000000  5760.000000
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1405792652.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data2022['공항_norm'] = sub_data2022['공항'].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1405792652.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data2022['공항_std'] = sub_data2022['공항'].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1405792652.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data2022['항구_norm'] = sub_data2022['항구'].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1405792652.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data2022['항구_std'] = sub_data2022['항구'].apply(lambda x: (x-value_mean)/value_std)

# %%
sub_data2022 = pd_data.tail(12)
print(sub_data2022)
print(sub_data2022.describe())

for n in ['공항', '항구']:
    value_min = sub_data2022[n].min()
    value_max = sub_data2022[n].max()
    value_std = sub_data2022[n].std()
    value_mean = sub_data2022[n].mean()
    sub_data2022[n+'_norm'] = sub_data2022[n].apply(lambda x: (x-value_min)/(value_max-value_min))
    sub_data2022[n+'_std'] = sub_data2022[n].apply(lambda x: (x-value_mean)/value_std)

    
    
    
    


_, axe = plt.subplots()
axe.plot(sub_data2022['공항_norm'])
axe.plot(sub_data2022['항구_norm'])

_, axe = plt.subplots()
axe.plot(sub_data2022['공항_std'])
axe.plot(sub_data2022['항구_std'])
# Out:
#          시점      공항    항구
# 0   2022.01     938  3279
# 1   2022.02     855  3179
# 2   2022.03     986  3418
# 3   2022.04    1823  3158
# 4   2022.05    3418  3231
# 5   2022.06    7835  3105
# 6   2022.07   42841  3326
# 7   2022.08   47261  3533
# 8   2022.09   37030  2682
# 9   2022.10   71579  3494
# 10  2022.11  126419  3687
# 11  2022.12  192723  5760
#                 시점             공항           항구
# count    12.000000      12.000000    12.000000
# mean   2022.065000   44475.666667  3487.666667
# std       0.036056   60324.578943   759.498918
# min    2022.010000     855.000000  2682.000000
# 25%    2022.037500    1613.750000  3173.750000
# 50%    2022.065000   22432.500000  3302.500000
# 75%    2022.092500   53340.500000  3503.750000
# max    2022.120000  192723.000000  5760.000000
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\353145297.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data2022[n+'_norm'] = sub_data2022[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\353145297.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data2022[n+'_std'] = sub_data2022[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\353145297.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data2022[n+'_norm'] = sub_data2022[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\353145297.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data2022[n+'_std'] = sub_data2022[n].apply(lambda x: (x-value_mean)/value_std)

# %%
df_combined = pd.read_csv('내국인출국교통수단별_2.csv', encoding='cp949', header=1)



df_combined.drop('계', axis =1, inplace=True)
df_combined.head()

df_combined.columns = ['시점', '공항', '항구']
print(df_combined)


# 공항, 항구 년중 월별 출국 인원 plot
# normalization / standardization 적용, plot
# 2018부터 2022년까지 추이 보기.
# Out:
#          시점      공항     항구
# 0   2015.01  226687  50545
# 1   2015.02  173950  44152
# 2   2015.03  175351  36822
# 3   2015.04  195851  46589
# 4   2015.05  199356  54680
# ..      ...     ...    ...
# 91  2022.08   47261   3533
# 92  2022.09   37030   2682
# 93  2022.10   71579   3494
# 94  2022.11  126419   3687
# 95  2022.12  192723   5760
#
# [96 rows x 3 columns]

# %%
print(df_combined)
for i in range(8):
    #print(i, 12*i, 12*(i+1))
    sub_data = df_combined.iloc[12*i:12*(1+i)]
    #print(sub_data)
    
    for n in ['공항', '항구']:
        value_min = sub_data[n].min()
        value_max = sub_data[n].max()
        value_std = sub_data[n].std()
        value_mean = sub_data[n].mean()
        sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
        sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
    
    _, axe = plt.subplots()
    axe.plot(sub_data['공항'])
    axe.plot(sub_data['항구'])
    
    _, axe = plt.subplots()
    axe.plot(sub_data['공항_norm'])
    axe.plot(sub_data['항구_norm'])

    _, axe = plt.subplots()
    axe.plot(sub_data['공항_std'])
    axe.plot(sub_data['항구_std'])
# Out:
#          시점      공항     항구
# 0   2015.01  226687  50545
# 1   2015.02  173950  44152
# 2   2015.03  175351  36822
# 3   2015.04  195851  46589
# 4   2015.05  199356  54680
# ..      ...     ...    ...
# 91  2022.08   47261   3533
# 92  2022.09   37030   2682
# 93  2022.10   71579   3494
# 94  2022.11  126419   3687
# 95  2022.12  192723   5760
#
# [96 rows x 3 columns]
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:23: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   _, axe = plt.subplots()
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_norm'] = sub_data[n].apply(lambda x: (x-value_min)/(value_max-value_min))
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_1812\1612466609.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_data[n+'_std'] = sub_data[n].apply(lambda x: (x-value_mean)/value_std)
